# %%
#Hypothesis: A higher proportion of "Surfing" deaths are women due to their higher average fat content, and menstrual cycles.

import pandas as pd
import matplotlib.pyplot as plt
excel_file = 'GSAF5.xls'
shark_df = pd.read_excel(excel_file)
shark_df = shark_df.drop(shark_df.index[6257:])

activity = shark_df['Activity']
type(activity)

shark_df

shark_df = shark_df.drop(shark_df.index[2036::])

shark_df
# Out:
#        Case Number                       Date    Year          Type  \
# 0       2018.04.03                03-Apr-2018  2018.0    Unprovoked
# 1       2018.03.31                31-Mar-2018  2018.0    Unprovoked
# 2       2018.03.14                14-Mar-2018  2018.0    Unprovoked
# 3     2018.03.09.b                 9-Mar-2018  2018.0    Unprovoked
# 4     2018.03.09.a                 9-Mar-2018  2018.0    Unprovoked
# 5       2018.02.24                24-Feb-2018  2018.0    Unprovoked
# 6       2018.02.23                23-Feb-2018  2018.0    Unprovoked
# 7       2018.02.17                18-Feb-2018  2018.0      Provoked
# 8       2018.02.15                15-Feb-2018  2018.0    Unprovoked
# 9       2018.02.11                11-Feb-2018  2018.0       Invalid
# 10      2018.02.03                03-Feb-2018  2018.0    Unprovoked
# 11    2018.01.28.R       Reported 28-Jan-2018  2018.0    Unprovoked
# 12      2018.01.21                21-Jan-2018  2018.0    Unprovoked
# ...

# %%
shark_df.Year.plot(kind='hist')
plt.show()

# %%
shark_df.Area.unique()
# Out:
# array(['Eastern Cape Province', 'Hawaii', 'Western Australia', 'Victoria',
#        'KwaZulu-Natal', 'New South Wales', 'Boi Island, Victoria',
#        'Galapagos Islands', nan, 'Fernando de Noronha', 'California',
#        'Sepang', 'Cocos Island', 'Florida', 'Holquin Province',
#        'Queensland', 'Pamplemousses ', 'South Australia', 'North Island',
#        'Western Cape Province', 'New York', 'Canary Islands',
#        ' Upolu Island', 'Westerm Australia', 'Shizuoka Prefecture',
#        'Texas', 'Castellón', 'Massachusetts', 'South Carolina',
#        'Red Sea Protectorate', 'New Providence District',
#        '40 miles off Grand Bahama Island', 'Ascension Island',
#        'New Jersey', 'Majorca', 'Washington', 'Tabasco', 'Anjouan',
#        'Ibiza Island', 'Marquesas', 'South Devon', 'New Providence ',
#        'Sharjah, ', 'Baja California Sur', 'Saint-Leu', 'South Island',
#        'Luzon Island', 'Great Exuma', 'Saint-Andre', 'Pernambuco',
# ...

# %%
surf_deaths = shark_df.loc[(shark_df['Activity']=="Surfing")]

surf_deaths.count
#959
#959 of the 6256 shark attacks since 1779 have been surfers

#That's only 15.3% of total recorded shark attacks in the world since 1779
# Out:
# <bound method DataFrame.count of        Case Number                  Date    Year        Type  \
# 0       2018.04.03           03-Apr-2018  2018.0  Unprovoked
# 4     2018.03.09.a            9-Mar-2018  2018.0  Unprovoked
# 14      2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 15      2018.01.05           05-Jan-2018  2018.0  Unprovoked
# 16      2017.12.31           31-Dec-2017  2017.0  Unprovoked
# 17      2017.12.30           30-Dec-2017  2017.0  Unprovoked
# 24      2017.11.18           18-Nov-2017  2017.0  Unprovoked
# 25    2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 26      2017.11.13           13-Nov-2017  2017.0  Unprovoked
# 29      2017.10.28           28-Oct-2017  2017.0  Unprovoked
# 37      2017.10.09           09-Oct-2017  2017.0  Unprovoked
# 40    2017.09.25.b           25-Sep-2017  2017.0  Unprovoked
# 41    2017.09.25.a           25-Sep-2017  2017.0  Unprovoked
# 42    2017.09.24.b           24-Sep-2017  2017.0     Invalid
# ...

# %%
shark_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2036 entries, 0 to 2035
# Data columns (total 24 columns):
# Case Number               2036 non-null object
# Date                      2036 non-null object
# Year                      2035 non-null float64
# Type                      2034 non-null object
# Country                   2034 non-null object
# Area                      1949 non-null object
# Location                  1948 non-null object
# Activity                  1945 non-null object
# Name                      2004 non-null object
# Sex                       1933 non-null object
# Age                       1527 non-null object
# Injury                    2034 non-null object
# Fatal (Y/N)               1875 non-null object
# Time                      1453 non-null object
# Species                   1341 non-null object
# Investigator or Source    2031 non-null object
# pdf                       2036 non-null object
# href formula              2036 non-null object
# ...

# %%
shark_df['Activity'].head(200)
# Out:
# 0                       Surfing
# 1       Stand-Up Paddleboarding
# 2                        Wading
# 3                      Swimming
# 4                       Surfing
# 5                  Scuba Diving
# 6                      Swimming
# 7      Kayak fishing for sharks
# 8                       Walking
# 9                 Cleaning fish
# 10                   Snorkeling
# 11                          NaN
# 12                 Spearfishing
# 13                  Free diving
# 14                      Surfing
# 15                      Surfing
# 16                      Surfing
# 17                      Surfing
# 18             Fishing / Wading
# 19                   Snorkeling
# 20                 Scuba Diving
# 21                 Scuba diving
# 22             2 boats capsized
# 23                 Spearfishing
# 24                      Surfing
# 25                      Surfing
# 26                      Surfing
# 27                Night bathing
# 28                   Snorkeling
# ...

# %%
print(shark_df)
# Out:
#        Case Number                       Date    Year          Type  \
# 0       2018.04.03                03-Apr-2018  2018.0    Unprovoked
# 1       2018.03.31                31-Mar-2018  2018.0    Unprovoked
# 2       2018.03.14                14-Mar-2018  2018.0    Unprovoked
# 3     2018.03.09.b                 9-Mar-2018  2018.0    Unprovoked
# 4     2018.03.09.a                 9-Mar-2018  2018.0    Unprovoked
# 5       2018.02.24                24-Feb-2018  2018.0    Unprovoked
# 6       2018.02.23                23-Feb-2018  2018.0    Unprovoked
# 7       2018.02.17                18-Feb-2018  2018.0      Provoked
# 8       2018.02.15                15-Feb-2018  2018.0    Unprovoked
# 9       2018.02.11                11-Feb-2018  2018.0       Invalid
# 10      2018.02.03                03-Feb-2018  2018.0    Unprovoked
# 11    2018.01.28.R       Reported 28-Jan-2018  2018.0    Unprovoked
# 12      2018.01.21                21-Jan-2018  2018.0    Unprovoked
# ...

# %% [markdown]
# ######

# %%
shark_df.Activity.unique()
# Out:
# array(['Surfing', 'Stand-Up Paddleboarding', 'Wading', 'Swimming',
#        'Scuba Diving', 'Kayak fishing for sharks', 'Walking',
#        'Cleaning fish', 'Snorkeling', nan, 'Spearfishing', 'Free diving',
#        'Fishing / Wading', 'Scuba diving', '2 boats capsized',
#        'Night bathing', 'Surfing ', 'Kayaking / Fishing', 'Kayaking',
#        'Body surfing', 'Fishing', 'Swimming, poaching abalone',
#        'Canoeing', 'SUP', 'Skimboarding', 'Body boarding',
#        'Feeding sharks', 'Touching a shark', 'Fishing ',
#        'Attempting to lasso a shark', 'Photo shoot', 'Paddle boarding',
#        'Kakaying', 'Washing hands', 'Grabbing shark for a selfie',
#        'Kayak fishing', 'Tagging sharks', 'Surf skiing ', 'Surf fishing',
#        'Floating', 'Cage Diving', 'Surfng', 'Kite surfing',
#        'Boogie boarding', 'SUP Foil boarding', 'Lobstering',
#        'Fishing in Alabama Deep Fishing Rodeo', 'Fishing for squid',
# ...

# %%
surf_deaths
# Out:
#        Case Number                  Date    Year        Type  \
# 0       2018.04.03           03-Apr-2018  2018.0  Unprovoked
# 4     2018.03.09.a            9-Mar-2018  2018.0  Unprovoked
# 14      2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 15      2018.01.05           05-Jan-2018  2018.0  Unprovoked
# 16      2017.12.31           31-Dec-2017  2017.0  Unprovoked
# 17      2017.12.30           30-Dec-2017  2017.0  Unprovoked
# 24      2017.11.18           18-Nov-2017  2017.0  Unprovoked
# 25    2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 26      2017.11.13           13-Nov-2017  2017.0  Unprovoked
# 29      2017.10.28           28-Oct-2017  2017.0  Unprovoked
# 37      2017.10.09           09-Oct-2017  2017.0  Unprovoked
# 40    2017.09.25.b           25-Sep-2017  2017.0  Unprovoked
# 41    2017.09.25.a           25-Sep-2017  2017.0  Unprovoked
# 42    2017.09.24.b           24-Sep-2017  2017.0     Invalid
# ...

# %%
surf_deaths['Sex '].unique()
# Out:
# array(['M', 'F', nan, 'lli'], dtype=object)

# %%
M_surf_deaths = surf_deaths.loc[(surf_deaths['Sex ']=="M")]

M_surf_deaths

M_surf_deaths.head(560)

#Index number 2035 is the last one within the years 2000 to the present.
# Out:
#        Case Number                  Date    Year        Type  \
# 0       2018.04.03           03-Apr-2018  2018.0  Unprovoked
# 4     2018.03.09.a            9-Mar-2018  2018.0  Unprovoked
# 14      2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 15      2018.01.05           05-Jan-2018  2018.0  Unprovoked
# 25    2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked
# 26      2017.11.13           13-Nov-2017  2017.0  Unprovoked
# 29      2017.10.28           28-Oct-2017  2017.0  Unprovoked
# 37      2017.10.09           09-Oct-2017  2017.0  Unprovoked
# 40    2017.09.25.b           25-Sep-2017  2017.0  Unprovoked
# 41    2017.09.25.a           25-Sep-2017  2017.0  Unprovoked
# 42    2017.09.24.b           24-Sep-2017  2017.0     Invalid
# 43    2017.09.24.a           24-Sep-2017  2017.0  Unprovoked
# 44      2017.09.20           20-Sep-2017  2017.0  Unprovoked
# 46    2017.09.16.a           16-Sep-2017  2017.0  Unprovoked
# ...

# %%
F_surf_deaths = surf_deaths.loc[(surf_deaths['Sex ']=="F")]

F_surf_deaths

#878 of 959 Surfing deaths have been male

#55 of 959 Surfing deaths have been female
# Out:
#        Case Number          Date    Year        Type       Country  \
# 16      2017.12.31   31-Dec-2017  2017.0  Unprovoked           USA
# 17      2017.12.30   30-Dec-2017  2017.0  Unprovoked           USA
# 24      2017.11.18   18-Nov-2017  2017.0  Unprovoked           USA
# 85      2017.07.07   07-Jul-2017  2017.0  Unprovoked  SOUTH AFRICA
# 96    2017.06.10.b   10-Jun-2017  2017.0  Unprovoked     AUSTRALIA
# 107     2017.05.03   03-May-2017  2017.0     Invalid           USA
# 110   2017.04.29.b   29-Apr-2017  2017.0  Unprovoked           USA
# 117   2017.04.17.a   17-Apr-2017  2017.0  Unprovoked     AUSTRALIA
# 120   2017.04.12.b   12-Apr-2017  2017.0  Unprovoked           USA
# 122     2017.04.11   11-Apr-2017  2017.0  Unprovoked           USA
# 206   2016.07.16.b   16-Jul-2016  2016.0  Unprovoked           USA
# 274     2016.01.25   25-Jan-2016  2016.0  Unprovoked           USA
# 295     2015.12.23   07-Nov-2015  2015.0     Invalid           USA
# ...

# %%
total_surf_deaths = surf_deaths['Sex ']

total_surf_deaths
# Out:
# 0         M
# 4         M
# 14        M
# 15        M
# 16        F
# 17        F
# 24        F
# 25        M
# 26        M
# 29        M
# 37        M
# 40        M
# 41        M
# 42        M
# 43        M
# 44        M
# 46        M
# 50        M
# 52        M
# 55        M
# 58        M
# 59        M
# 74        M
# 81        M
# 85        F
# 89        M
# 93        M
# 96        F
# 97        M
# 107       F
#        ...
# 1920      M
# 1921      M
# 1922      M
# 1923    NaN
# 1924      M
# 1928      M
# 1930      M
# 1936      M
# 1940      M
# 1947      F
# 1954      M
# 1956      M
# 1959      M
# 1960      M
# 1962      M
# 1964      M
# 1965      M
# 1967      M
# 1970      F
# 1976      M
# 1990      M
# 1991      M
# 1992      M
# 1993      M
# 1994      M
# 2009      M
# 2023      M
# 2025      M
# 2034      M
# 2035      M
# Name: Sex , Length: 618, dtype: object

# %%
total_surf_deaths = total_surf_deaths.dropna()

# %%
total_surf_deaths = total_surf_deaths.drop(total_surf_deaths[total_surf_deaths=='lli'].index)

total_surf_deaths
# Out:
# 0       M
# 4       M
# 14      M
# 15      M
# 16      F
# 17      F
# 24      F
# 25      M
# 26      M
# 29      M
# 37      M
# 40      M
# 41      M
# 42      M
# 43      M
# 44      M
# 46      M
# 50      M
# 52      M
# 55      M
# 58      M
# 59      M
# 74      M
# 81      M
# 85      F
# 89      M
# 93      M
# 96      F
# 97      M
# 107     F
#        ..
# 1919    M
# 1920    M
# 1921    M
# 1922    M
# 1924    M
# 1928    M
# 1930    M
# 1936    M
# 1940    M
# 1947    F
# 1954    M
# 1956    M
# 1959    M
# 1960    M
# 1962    M
# 1964    M
# 1965    M
# 1967    M
# 1970    F
# 1976    M
# 1990    M
# 1991    M
# 1992    M
# 1993    M
# 1994    M
# 2009    M
# 2023    M
# 2025    M
# 2034    M
# 2035    M
# Name: Sex , Length: 608, dtype: object

# %%
total_surf_deaths.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
import seaborn as sns
from collections import Counter

c = Counter(total_surf_deaths)

men = c['M']
women = c['F']

bar_heights = (men, women)
x = (1, 1.2)

fig, ax = plt.subplots()
width = .1

ax.bar(x, bar_heights, width)

ax.set_xticks([1, 1.2])
ax.set_xticklabels(['Male', 'Female'])

plt.title("Surf Deaths Since 2000")

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.spines["bottom"].set_visible(False)

plt.show()

# %%
print(men)

print(women)

sns.swarmplot(x="Sex", y="Deaths", hue="Sex", data=total_surf_deaths);

plt.show()

#Don't have time to fix this right now, maybe I'll come back.
# Out:
# 555
# 53
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-245eb29afdea> in <module>()
#       3 print(women)
#       4
# ----> 5 sns.swarmplot(x="Sex", y="Deaths", hue="Sex", data=total_surf_deaths);
#       6
#       7 plt.show()
#
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2784
#    2785     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
# -> 2786                             dodge, orient, color, palette)
#    2787     if ax is None:
#    2788         ax = plt.gca()
#
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1201                  dodge, orient, color, palette):
# ...

# %%
#Roughly 9% of surfing deaths were women since the year 2000.

#Makes sense if 10% of women surf.  My hypothesis is incorrect.  I thought a higher
#percentage of women would die surfing, because sharks should like them more.

# %% [markdown]
# 53*10

# %%
#If I skew the data a bit... Female surfers are 24% more likely to get attacked by sharks than male surfers, historically.

#About 33 "Surfing" deaths per year.
